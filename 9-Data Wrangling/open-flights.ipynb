# %% [markdown]
# ### Open Flights Data Wrangling
#
# To practice, you are going to wrangle data from OpenFlights.  You can read about it here:
#
# http://openflights.org/data.html
#
# This includes three main files, one for each airport, one for each airline, and one for each route.  They can be merged or joined with the appropriate fields.  I have modified the files slightly to include a header row in the .dat files, which makes it a bit easier for you.
#
# You are required to work through the problems below.  This may take some time.  Be persistent, and ask questions or seek help as needed.

# %%
import pandas as pd
import numpy as np

# %%
# These files use \N as a missing value indicator.  When reading the CSVs, we will tell
# it to use that value as missing or NA.  The double backslash is required because
# otherwise it will interpret \N as a carriage return. 
airports = pd.read_csv('data/airports.txt', na_values=['\\N'])
airlines = pd.read_csv('data/airlines.txt', na_values=['\\N'])
routes = pd.read_csv('data/routes.txt', na_values=['\\N'])

# %% [markdown]
# 1) Start by seeing what's in the data.  What columns are there?  What data types are the columns?
#
# Remember, 'object' means it is a string, while the numerical values can be floats or ints.  Sometimes you will have problems if it reads numeric data in as strings.  If that happens, you can use the function .astype() to convert it.  Look it up in the pandas API to get more details

# %%
routes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67663 entries, 0 to 67662
# Data columns (total 9 columns):
# Airline                   67663 non-null object
# AirlineID                 67184 non-null float64
# Source Airport            67663 non-null object
# Source airport ID         67443 non-null float64
# Destination airport       67663 non-null object
# Destination airport ID    67442 non-null float64
# Codeshare                 14597 non-null object
# Stops                     67663 non-null int64
# Equipment                 67645 non-null object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 4.6+ MB

# %%
airlines
# Out:
#       ﻿"Airline"                                            ID  \
# 0             -1                                       Unknown
# 1              1                                Private flight
# 2              2                                   135 Airways
# 3              3                                 1Time Airline
# 4              4  2 Sqn No 1 Elementary Flying Training School
# 5              5                               213 Flight Unit
# 6              6                 223 Flight Unit State Airline
# 7              7                             224th Flight Unit
# 8              8                                   247 Jet Ltd
# 9              9                                   3D Aviation
# 10            10                                   40-Mile Air
# 11            11                                        4D Air
# 12            12                        611897 Alberta Limited
# 13            13                              Ansett Australia
# 14            14                          Abacus International
# 15            15                               Abelag Aviation
# 16            16                                Army Air Corps
# 17            17                     Aero Aviation Centre Ltd.
# 18            18     Aero Servicios Ejecutivos Internacionales
# 19            19                                   Aero Biniza
# 20            20                                 Aero Albatros
# 21            21                                    Aigle Azur
# 22            22                                Aloha Airlines
# 23            23                             Alaska Island Air
# 24            24                             American Airlines
# 25            25               Aviation Management Corporation
# 26            26                       Atlantis Airlines (USA)
# 27            27                            Aerovista Airlines
# 28            28                               Asiana Airlines
# 29            29                               Askari Aviation
# ...          ...                                           ...
# 6132       20827                                    Fly France
# 6133       20875                                 Jota Aviation
# 6134       20881                                    Europe Jet
# 6135       20923                                        COBALT
# 6136       20931                      Southern Airways Express
# 6137       20961       Deutsche Luftverkehrsgesellschaft (DLT)
# 6138       20962                                   Orenburzhie
# 6139       20963                            Atlantic Air Cargo
# 6140       20976                          World Scale Airlines
# 6141       20978                                All America US
# 6142       20986   University of Birmingham Air Squadron (RAF)
# 6143       20991                                Choice Airways
# 6144       20994                                Aruba Airlines
# 6145       20995                                     BudgetAir
# 6146       20996                               Dynamic Airways
# 6147       21012                                       Fly One
# 6148       21021                                       Nordica
# 6149       21036                              Tez Jet Airlines
# 6150       21043                                      Kush Air
# 6151       21056                                         Dummy
# 6152       21124                                        ViaAir
# 6153       21131                              All America BOPY
# 6154       21179                              Thai Vietjet Air
# 6155       21181                              Air Andaman (2Y)
# 6156       21240                     TDA Toa Domestic Airlines
# 6157       21248                                   GX Airlines
# 6158       21251                        Lynx Aviation (L3/SSX)
# 6159       21268                               Jetgo Australia
# 6160       21270                                  Air Carnival
# 6161       21317                                 Svyaz Rossiya
#
#                        Name Alias IATA             ICAO              Callsign  \
# 0                       NaN     -  NaN              NaN                   NaN
# 1                       NaN     -  NaN              NaN                   NaN
# 2                       NaN   NaN  GNL          GENERAL         United States
# 3                       NaN    1T  RNX          NEXTIME          South Africa
# 4                       NaN   NaN  WYT              NaN        United Kingdom
# 5                       NaN   NaN  TFU              NaN                Russia
# 6                       NaN   NaN  CHD   CHKALOVSK-AVIA                Russia
# 7                       NaN   NaN  TTF       CARGO UNIT                Russia
# 8                       NaN   NaN  TWF     CLOUD RUNNER        United Kingdom
# 9                       NaN   NaN  SEC          SECUREX         United States
# 10                      NaN    Q5  MLA         MILE-AIR         United States
# 11                      NaN   NaN  QRT          QUARTET              Thailand
# 12                      NaN   NaN  THD            DONUT                Canada
# 13                      NaN    AN  AAA           ANSETT             Australia
# 14                      NaN    1B  NaN              NaN             Singapore
# 15                      NaN    W9  AAB              ABG               Belgium
# 16                      NaN   NaN  AAC          ARMYAIR        United Kingdom
# 17                      NaN   NaN  AAD          SUNRISE                Canada
# 18                      NaN   NaN  SII           ASEISA                Mexico
# 19                      NaN   NaN  BZS           BINIZA                Mexico
# 20                      NaN   NaN  ABM  ALBATROS ESPANA                 Spain
# 21                      NaN    ZI  AAF       AIGLE AZUR                France
# 22                      NaN    AQ  AAH            ALOHA         United States
# 23                      NaN   NaN  AAK    ALASKA ISLAND         United States
# 24                      NaN    AA  AAL         AMERICAN         United States
# 25                      NaN   NaN  AAM          AM CORP         United States
# 26                      NaN   NaN  AAO     ATLANTIS AIR         United States
# 27                      NaN   NaN  AAP  AEROVISTA GROUP  United Arab Emirates
# 28                      NaN    OZ  AAR           ASIANA     Republic of Korea
# 29                      NaN    4K  AAS           AL-AAS              Pakistan
# ...                     ...   ...  ...              ...                   ...
# 6132             Fly France    FF  FRF              NaN                France
# 6133                    NaN   NaN  ENZ             ENZO        United Kingdom
# 6134             Europe Jet    EX  EU9              NaN                France
# 6135                 COBALT   NaN  FCB           COBALT                Cyprus
# 6136        Sun Air Express   NaN  LTD       LIGHTSPEED         United States
# 6137                    NaN    DW  DWD              NaN               Germany
# 6138                    NaN   NaN  ORG              NaN                Russia
# 6139                    NaN    K3  NaN              NaN         United States
# 6140            World Scale    W3  WSS              NaN         United States
# 6141         All America US    AG  SSA              NaN         United States
# 6142               8AEF RAF   NaN  UAY              UAY        United Kingdom
# 6143                    NaN   NaN  CSX              NaN         United States
# 6144                    NaN   NaN  ARU              NaN                 Aruba
# 6145              BudgetAir    1K  BG1              NaN               Germany
# 6146                    NaN   NaN  DYA              NaN         United States
# 6147                Fly One    F5  FI5              NaN               Moldova
# 6148                    NaN    EE  NaN            REVAL               Estonia
# 6149                    NaN   NaN  TEZ              NaN            Kyrgyzstan
# 6150                    NaN   NaN  KUH              NaN           South Sudan
# 6151                    NaN    0E  NaN              NaN                France
# 6152  Charter Air Transport   NaN  SRY         Stingray         United States
# 6153       All America BOPY    0P  PYB             BOPY              Paraguay
# 6154                    NaN   NaN  TVJ     THAIVIET JET              Thailand
# 6155                    NaN    2Y  AOW      AIR ANDAMAN              Thailand
# 6156                    TDA   NaN  TDA        Toa Domes                 Japan
# 6157                    NaN   NaN  CBG            SPRAY                 China
# 6158                    NaN   NaN  SSX           Shasta         United States
# 6159                    NaN    JG  NaN              NaN             Australia
# 6160                    NaN    2S  NaN              NaN                 India
# 6161      Russian Commuter     7R  SJM  RussianConnecty                Russia
#
#      Country  Active
# 0          Y     NaN
# 1          Y     NaN
# 2          N     NaN
# 3          Y     NaN
# 4          N     NaN
# 5          N     NaN
# 6          N     NaN
# 7          N     NaN
# 8          N     NaN
# 9          N     NaN
# 10         Y     NaN
# 11         N     NaN
# 12         N     NaN
# 13         Y     NaN
# 14         Y     NaN
# 15         N     NaN
# 16         N     NaN
# 17         N     NaN
# 18         N     NaN
# 19         N     NaN
# 20         N     NaN
# 21         Y     NaN
# 22         Y     NaN
# 23         N     NaN
# 24         Y     NaN
# 25         N     NaN
# 26         N     NaN
# 27         N     NaN
# 28         Y     NaN
# 29         Y     NaN
# ...      ...     ...
# 6132       Y     NaN
# 6133       Y     NaN
# 6134       Y     NaN
# 6135       Y     NaN
# 6136       Y     NaN
# 6137       N     NaN
# 6138       Y     NaN
# 6139       N     NaN
# 6140       Y     NaN
# 6141       Y     NaN
# 6142       Y     NaN
# 6143       Y     NaN
# 6144       Y     NaN
# 6145       Y     NaN
# 6146       Y     NaN
# 6147       Y     NaN
# 6148       Y     NaN
# 6149       Y     NaN
# 6150       Y     NaN
# 6151       N     NaN
# 6152       Y     NaN
# 6153       Y     NaN
# 6154       Y     NaN
# 6155       N     NaN
# 6156       N     NaN
# 6157       Y     NaN
# 6158       N     NaN
# 6159       Y     NaN
# 6160       Y     NaN
# 6161       Y     NaN
#
# [6162 rows x 9 columns]

# %%
airlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6162 entries, 0 to 6161
# Data columns (total 8 columns):
# ﻿"AirlineID"    6162 non-null int64
# Name            6162 non-null object
# Alias           179 non-null object
# IATA            1534 non-null object
# ICAO            5887 non-null object
# Callsign        5351 non-null object
# Country         6144 non-null object
# Active          6162 non-null object
# dtypes: int64(1), object(7)
# memory usage: 385.2+ KB

# %%
airlines.head()
# Out:
#    ﻿"AirlineID"                                          Name Alias IATA ICAO  \
# 0            -1                                       Unknown   NaN    -  NaN
# 1             1                                Private flight   NaN    -  NaN
# 2             2                                   135 Airways   NaN  NaN  GNL
# 3             3                                 1Time Airline   NaN   1T  RNX
# 4             4  2 Sqn No 1 Elementary Flying Training School   NaN  NaN  WYT
#
#   Callsign         Country Active
# 0      NaN             NaN      Y
# 1      NaN             NaN      Y
# 2  GENERAL   United States      N
# 3  NEXTIME    South Africa      Y
# 4      NaN  United Kingdom      N

# %%
airlines.rename(columns={'"AirlineID"':'AirlineID'}, inplace=True)

# %%
airlines.head()
# Out:
#    ﻿"AirlineID"                                          Name Alias IATA ICAO  \
# 0            -1                                       Unknown   NaN    -  NaN
# 1             1                                Private flight   NaN    -  NaN
# 2             2                                   135 Airways   NaN  NaN  GNL
# 3             3                                 1Time Airline   NaN   1T  RNX
# 4             4  2 Sqn No 1 Elementary Flying Training School   NaN  NaN  WYT
#
#   Callsign         Country Active
# 0      NaN             NaN      Y
# 1      NaN             NaN      Y
# 2  GENERAL   United States      N
# 3  NEXTIME    South Africa      Y
# 4      NaN  United Kingdom      N

# %%
routes.head()
# Out:
#   Airline  AirlineID Source Airport  Source airport ID Destination airport  \
# 0      2B      410.0            AER             2965.0                 KZN
# 1      2B      410.0            ASF             2966.0                 KZN
# 2      2B      410.0            ASF             2966.0                 MRV
# 3      2B      410.0            CEK             2968.0                 KZN
# 4      2B      410.0            CEK             2968.0                 OVB
#
#    Destination airport ID Codeshare  Stops Equipment
# 0                  2990.0       NaN      0       CR2
# 1                  2990.0       NaN      0       CR2
# 2                  2962.0       NaN      0       CR2
# 3                  2990.0       NaN      0       CR2
# 4                  4078.0       NaN      0       CR2

# %%
routes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67662 entries, 0 to 67661
# Data columns (total 9 columns):
# 2B            67662 non-null object
# 410           67183 non-null float64
# AER           67662 non-null object
# 2965          67442 non-null float64
# KZN           67662 non-null object
# 2990          67441 non-null float64
# Unnamed: 6    14597 non-null object
# 0             67662 non-null int64
# CR2           67644 non-null object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 4.6+ MB

# %%
print(len(routes))
routes.head()
# Out:
# 67662
#    2B    410  AER    2965  KZN    2990 Unnamed: 6  0  CR2
# 0  2B  410.0  ASF  2966.0  KZN  2990.0        NaN  0  CR2
# 1  2B  410.0  ASF  2966.0  MRV  2962.0        NaN  0  CR2
# 2  2B  410.0  CEK  2968.0  KZN  2990.0        NaN  0  CR2
# 3  2B  410.0  CEK  2968.0  OVB  4078.0        NaN  0  CR2
# 4  2B  410.0  DME  4029.0  KZN  2990.0        NaN  0  CR2

# %% [markdown]
# 2) Select just the routes that go to or from Lexington Bluegrass Airport, and store them in their own dataframe.
#
# The airport code is LEX.  You should have a much smaller dataframe.  How many inbound routes and how many outbound routes are there?

# %%
df = routes[routes['Source Airport'] == 'LEX']
print(len(df))
df
# Out:
# 20
#       Airline  AirlineID Source Airport  Source airport ID  \
# 3588       9E     3976.0            LEX             4017.0
# 5763       AA       24.0            LEX             4017.0
# 5764       AA       24.0            LEX             4017.0
# 5765       AA       24.0            LEX             4017.0
# 9641       AF      137.0            LEX             4017.0
# 21095      DL     2009.0            LEX             4017.0
# 21096      DL     2009.0            LEX             4017.0
# 21097      DL     2009.0            LEX             4017.0
# 21098      DL     2009.0            LEX             4017.0
# 21099      DL     2009.0            LEX             4017.0
# 29047      G4       35.0            LEX             4017.0
# 29048      G4       35.0            LEX             4017.0
# 29049      G4       35.0            LEX             4017.0
# 29050      G4       35.0            LEX             4017.0
# 36746      KL     3090.0            LEX             4017.0
# 57029      UA     5209.0            LEX             4017.0
# 57030      UA     5209.0            LEX             4017.0
# 59544      US     5265.0            LEX             4017.0
# 59545      US     5265.0            LEX             4017.0
# 59546      US     5265.0            LEX             4017.0
#
#       Destination airport  Destination airport ID Codeshare  Stops  \
# 3588                  ATL                  3682.0       NaN      0
# 5763                  CLT                  3876.0         Y      0
# 5764                  DFW                  3670.0         Y      0
# 5765                  ORD                  3830.0         Y      0
# 9641                  ATL                  3682.0         Y      0
# 21095                 ATL                  3682.0       NaN      0
# 21096                 DCA                  3520.0         Y      0
# 21097                 DTW                  3645.0         Y      0
# 21098                 LGA                  3697.0       NaN      0
# 21099                 MSP                  3858.0         Y      0
# 29047                 FLL                  3533.0       NaN      0
# 29048                 PGD                  7056.0       NaN      0
# 29049                 PIE                  3617.0       NaN      0
# 29050                 SFB                  4167.0       NaN      0
# 36746                 ATL                  3682.0         Y      0
# 57029                 IAH                  3550.0         Y      0
# 57030                 ORD                  3830.0         Y      0
# 59544                 CLT                  3876.0       NaN      0
# 59545                 DFW                  3670.0       NaN      0
# 59546                 ORD                  3830.0         Y      0
#
#          Equipment
# 3588           CRJ
# 5763       CR7 CRJ
# 5764       ERD ER4
# 5765       ERD ER4
# 9641       CRJ CR9
# 21095      M88 717
# 21096          CRJ
# 21097  CR7 CRJ CR9
# 21098          ERJ
# 21099          CRJ
# 29047          M80
# 29048          M80
# 29049          320
# 29050      M80 320
# 36746      CR9 CRJ
# 57029          ERJ
# 57030      ERJ CRJ
# 59544          CR7
# 59545          ERD
# 59546      ERD ER4

# %%
df2 = routes[routes['Destination airport'] == 'LEX']
print(len(df2))
df2
# Out:
# 20
#       Airline  AirlineID Source Airport  Source airport ID  \
# 3569       9E     3976.0            ATL             3682.0
# 4953       AA       24.0            CLT             3876.0
# 5247       AA       24.0            DFW             3670.0
# 6283       AA       24.0            ORD             3830.0
# 9097       AF      137.0            ATL             3682.0
# 20164      DL     2009.0            ATL             3682.0
# 20534      DL     2009.0            DCA             3520.0
# 20638      DL     2009.0            DTW             3645.0
# 21131      DL     2009.0            LGA             3697.0
# 21402      DL     2009.0            MSP             3858.0
# 28951      G4       35.0            FLL             3533.0
# 29090      G4       35.0            PGD             7056.0
# 29120      G4       35.0            PIE             3617.0
# 29187      G4       35.0            SFB             4167.0
# 36396      KL     3090.0            ATL             3682.0
# 56775      UA     5209.0            IAH             3550.0
# 57322      UA     5209.0            ORD             3830.0
# 58812      US     5265.0            CLT             3876.0
# 59096      US     5265.0            DFW             3670.0
# 59924      US     5265.0            ORD             3830.0
#
#       Destination airport  Destination airport ID Codeshare  Stops  \
# 3569                  LEX                  4017.0       NaN      0
# 4953                  LEX                  4017.0       NaN      0
# 5247                  LEX                  4017.0         Y      0
# 6283                  LEX                  4017.0         Y      0
# 9097                  LEX                  4017.0         Y      0
# 20164                 LEX                  4017.0       NaN      0
# 20534                 LEX                  4017.0         Y      0
# 20638                 LEX                  4017.0       NaN      0
# 21131                 LEX                  4017.0         Y      0
# 21402                 LEX                  4017.0         Y      0
# 28951                 LEX                  4017.0       NaN      0
# 29090                 LEX                  4017.0       NaN      0
# 29120                 LEX                  4017.0       NaN      0
# 29187                 LEX                  4017.0       NaN      0
# 36396                 LEX                  4017.0         Y      0
# 56775                 LEX                  4017.0         Y      0
# 57322                 LEX                  4017.0         Y      0
# 58812                 LEX                  4017.0       NaN      0
# 59096                 LEX                  4017.0       NaN      0
# 59924                 LEX                  4017.0         Y      0
#
#              Equipment
# 3569               CRJ
# 4953               CR7
# 5247           ERD ER4
# 6283           ERD ER4
# 9097   CR9 M88 CRJ 717
# 20164          M88 717
# 20534              CRJ
# 20638              717
# 21131              ERJ
# 21402              CRJ
# 28951              M80
# 29090              M80
# 29120              320
# 29187          M80 320
# 36396      CR9 M88 CRJ
# 56775              ERJ
# 57322          ERJ CRJ
# 58812              CR7
# 59096              ERD
# 59924          ERD ER4

# %% [markdown]
# 3) Now let's look at which airlines operate in and out of Lexington.  To do this, you need to merge the airline dataframe to the route dataframe.
#
# How many routes does each airline have?  The value_counts() method may be useful for answering this question.

# %%
pd.value_counts(df2['AirlineID'])
# Out:
# 2009.0    5
# 35.0      4
# 24.0      3
# 5265.0    3
# 5209.0    2
# 3090.0    1
# 137.0     1
# 3976.0    1
# Name: AirlineID, dtype: int64

# %%
pd.value_counts(df['AirlineID'])
# Out:
# 2009.0    5
# 35.0      4
# 24.0      3
# 5265.0    3
# 5209.0    2
# 3090.0    1
# 137.0     1
# 3976.0    1
# Name: AirlineID, dtype: int64

# %%
pd.merge?

# %%
airlines.head()
# Out:
#    ﻿"AirlineID"                                          Name Alias IATA ICAO  \
# 0            -1                                       Unknown   NaN    -  NaN
# 1             1                                Private flight   NaN    -  NaN
# 2             2                                   135 Airways   NaN  NaN  GNL
# 3             3                                 1Time Airline   NaN   1T  RNX
# 4             4  2 Sqn No 1 Elementary Flying Training School   NaN  NaN  WYT
#
#   Callsign         Country Active
# 0      NaN             NaN      Y
# 1      NaN             NaN      Y
# 2  GENERAL   United States      N
# 3  NEXTIME    South Africa      Y
# 4      NaN  United Kingdom      N

# %%
df_dep = pd.merge(df,airlines, left_on='AirlineID', right_on='"AirlineID"', how='left')
df_dep
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12368)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12322)()
#
# KeyError: '"AirlineID"'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-804b414b73be> in <module>()
# ----> 1 df_dep = pd.merge(df,airlines, left_on='AirlineID', right_on='"AirlineID"', how='left')
#       2 df_dep
#
# C:\Anaconda\lib\site-packages\pandas\tools\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      36                          right_on=right_on, left_index=left_index,
#      37                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 38                          copy=copy, indicator=indicator)
#      39     return op.get_result()
#      40 if __debug__:
#
# C:\Anaconda\lib\site-packages\pandas\tools\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator)
#     208         (self.left_join_keys,
#     209          self.right_join_keys,
# --> 210          self.join_names) = self._get_merge_keys()
#     211
#     212     def get_result(self):
#
# C:\Anaconda\lib\site-packages\pandas\tools\merge.py in _get_merge_keys(self)
#     432                 else:
#     433                     if not is_rkey(rk):
# --> 434                         right_keys.append(right[rk]._values)
#     435                         if lk == rk:
#     436                             # avoid key upcast in corner case (length-0)
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# C:\Anaconda\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Anaconda\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4154)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4018)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12368)()
#
# pandas\hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12322)()
#
# KeyError: '"AirlineID"'

# %%
df2.head()
# Out:
#      Airline  AirlineID Source Airport  Source airport ID Destination airport  \
# 3569      9E     3976.0            ATL             3682.0                 LEX
# 4953      AA       24.0            CLT             3876.0                 LEX
# 5247      AA       24.0            DFW             3670.0                 LEX
# 6283      AA       24.0            ORD             3830.0                 LEX
# 9097      AF      137.0            ATL             3682.0                 LEX
#
#       Destination airport ID Codeshare  Stops        Equipment
# 3569                  4017.0       NaN      0              CRJ
# 4953                  4017.0       NaN      0              CR7
# 5247                  4017.0         Y      0          ERD ER4
# 6283                  4017.0         Y      0          ERD ER4
# 9097                  4017.0         Y      0  CR9 M88 CRJ 717

# %%
df_arrive = pd.merge(df2,airlines, on='AirlineID', how='left')
df_arrive
# Out:
#    Airline  AirlineID SourceAirport  SourceAirportID DestAirport  \
# 0       9E     3976.0           ATL           3682.0         LEX
# 1       AA       24.0           CLT           3876.0         LEX
# 2       AA       24.0           DFW           3670.0         LEX
# 3       AA       24.0           ORD           3830.0         LEX
# 4       AF      137.0           ATL           3682.0         LEX
# 5       DL     2009.0           ATL           3682.0         LEX
# 6       DL     2009.0           DCA           3520.0         LEX
# 7       DL     2009.0           DTW           3645.0         LEX
# 8       DL     2009.0           LGA           3697.0         LEX
# 9       DL     2009.0           MSP           3858.0         LEX
# 10      G4       35.0           FLL           3533.0         LEX
# 11      G4       35.0           PGD           7056.0         LEX
# 12      G4       35.0           PIE           3617.0         LEX
# 13      G4       35.0           SFB           4167.0         LEX
# 14      KL     3090.0           ATL           3682.0         LEX
# 15      UA     5209.0           IAH           3550.0         LEX
# 16      UA     5209.0           ORD           3830.0         LEX
# 17      US     5265.0           CLT           3876.0         LEX
# 18      US     5265.0           DFW           3670.0         LEX
# 19      US     5265.0           ORD           3830.0         LEX
#
#     DestAirportID Codeshare  Stops        Equipment                      Name  \
# 0          4017.0       NaN      0              CRJ         Pinnacle Airlines
# 1          4017.0       NaN      0              CR7         American Airlines
# 2          4017.0         Y      0          ERD ER4         American Airlines
# 3          4017.0         Y      0          ERD ER4         American Airlines
# 4          4017.0         Y      0  CR9 M88 CRJ 717                Air France
# 5          4017.0       NaN      0          M88 717           Delta Air Lines
# 6          4017.0         Y      0              CRJ           Delta Air Lines
# 7          4017.0       NaN      0              717           Delta Air Lines
# 8          4017.0         Y      0              ERJ           Delta Air Lines
# 9          4017.0         Y      0              CRJ           Delta Air Lines
# 10         4017.0       NaN      0              M80             Allegiant Air
# 11         4017.0       NaN      0              M80             Allegiant Air
# 12         4017.0       NaN      0              320             Allegiant Air
# 13         4017.0       NaN      0          M80 320             Allegiant Air
# 14         4017.0         Y      0      CR9 M88 CRJ  KLM Royal Dutch Airlines
# 15         4017.0         Y      0              ERJ           United Airlines
# 16         4017.0         Y      0          ERJ CRJ           United Airlines
# 17         4017.0       NaN      0              CR7                US Airways
# 18         4017.0       NaN      0              ERD                US Airways
# 19         4017.0         Y      0          ERD ER4                US Airways
#
#    Alias IATA ICAO   Callsign        Country Active
# 0    NaN   9E  FLG   FLAGSHIP  United States      Y
# 1    NaN   AA  AAL   AMERICAN  United States      Y
# 2    NaN   AA  AAL   AMERICAN  United States      Y
# 3    NaN   AA  AAL   AMERICAN  United States      Y
# 4    NaN   AF  AFR   AIRFRANS         France      Y
# 5    NaN   DL  DAL      DELTA  United States      Y
# 6    NaN   DL  DAL      DELTA  United States      Y
# 7    NaN   DL  DAL      DELTA  United States      Y
# 8    NaN   DL  DAL      DELTA  United States      Y
# 9    NaN   DL  DAL      DELTA  United States      Y
# 10   NaN   G4  AAY  ALLEGIANT  United States      Y
# 11   NaN   G4  AAY  ALLEGIANT  United States      Y
# 12   NaN   G4  AAY  ALLEGIANT  United States      Y
# 13   NaN   G4  AAY  ALLEGIANT  United States      Y
# 14   NaN   KL  KLM        KLM    Netherlands      Y
# 15   NaN   UA  UAL     UNITED  United States      Y
# 16   NaN   UA  UAL     UNITED  United States      Y
# 17   NaN   US  USA    U S AIR  United States      Y
# 18   NaN   US  USA    U S AIR  United States      Y
# 19   NaN   US  USA    U S AIR  United States      Y

# %% [markdown]
# 4) It looks like there are some international airlines with Lexington routes.  To look at how many routes they have, create a new column in your dataframe called 'International', which is set to Y for an overseas airline and N for a domestic airline.  Calculate the percent of routes with an overseas airline.

# %%
df_arrive['International'][0] = 'N'
df_arrive.head()
# Out:
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#   Airline  AirlineID SourceAirport  SourceAirportID DestAirport  \
# 0      9E     3976.0           ATL           3682.0         LEX
# 1      AA       24.0           CLT           3876.0         LEX
# 2      AA       24.0           DFW           3670.0         LEX
# 3      AA       24.0           ORD           3830.0         LEX
# 4      AF      137.0           ATL           3682.0         LEX
#
#    DestAirportID Codeshare  Stops        Equipment               Name Alias  \
# 0         4017.0       NaN      0              CRJ  Pinnacle Airlines   NaN
# 1         4017.0       NaN      0              CR7  American Airlines   NaN
# 2         4017.0         Y      0          ERD ER4  American Airlines   NaN
# 3         4017.0         Y      0          ERD ER4  American Airlines   NaN
# 4         4017.0         Y      0  CR9 M88 CRJ 717         Air France   NaN
#
#   IATA ICAO  Callsign        Country Active International
# 0   9E  FLG  FLAGSHIP  United States      Y             N
# 1   AA  AAL  AMERICAN  United States      Y             N
# 2   AA  AAL  AMERICAN  United States      Y             N
# 3   AA  AAL  AMERICAN  United States      Y             N
# 4   AF  AFR  AIRFRANS         France      Y             Y

# %%
for label in df_arrive.index:
    if df_arrive.Country[label] == 'United States':
        df_arrive['International'][label] = 'N'
    else:
        df_arrive['International'][label] = 'Y'
        
df_arrive
# Out:
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Airline  AirlineID SourceAirport  SourceAirportID DestAirport  \
# 0       9E     3976.0           ATL           3682.0         LEX
# 1       AA       24.0           CLT           3876.0         LEX
# 2       AA       24.0           DFW           3670.0         LEX
# 3       AA       24.0           ORD           3830.0         LEX
# 4       AF      137.0           ATL           3682.0         LEX
# 5       DL     2009.0           ATL           3682.0         LEX
# 6       DL     2009.0           DCA           3520.0         LEX
# 7       DL     2009.0           DTW           3645.0         LEX
# 8       DL     2009.0           LGA           3697.0         LEX
# 9       DL     2009.0           MSP           3858.0         LEX
# 10      G4       35.0           FLL           3533.0         LEX
# 11      G4       35.0           PGD           7056.0         LEX
# 12      G4       35.0           PIE           3617.0         LEX
# 13      G4       35.0           SFB           4167.0         LEX
# 14      KL     3090.0           ATL           3682.0         LEX
# 15      UA     5209.0           IAH           3550.0         LEX
# 16      UA     5209.0           ORD           3830.0         LEX
# 17      US     5265.0           CLT           3876.0         LEX
# 18      US     5265.0           DFW           3670.0         LEX
# 19      US     5265.0           ORD           3830.0         LEX
#
#     DestAirportID Codeshare  Stops        Equipment                      Name  \
# 0          4017.0       NaN      0              CRJ         Pinnacle Airlines
# 1          4017.0       NaN      0              CR7         American Airlines
# 2          4017.0         Y      0          ERD ER4         American Airlines
# 3          4017.0         Y      0          ERD ER4         American Airlines
# 4          4017.0         Y      0  CR9 M88 CRJ 717                Air France
# 5          4017.0       NaN      0          M88 717           Delta Air Lines
# 6          4017.0         Y      0              CRJ           Delta Air Lines
# 7          4017.0       NaN      0              717           Delta Air Lines
# 8          4017.0         Y      0              ERJ           Delta Air Lines
# 9          4017.0         Y      0              CRJ           Delta Air Lines
# 10         4017.0       NaN      0              M80             Allegiant Air
# 11         4017.0       NaN      0              M80             Allegiant Air
# 12         4017.0       NaN      0              320             Allegiant Air
# 13         4017.0       NaN      0          M80 320             Allegiant Air
# 14         4017.0         Y      0      CR9 M88 CRJ  KLM Royal Dutch Airlines
# 15         4017.0         Y      0              ERJ           United Airlines
# 16         4017.0         Y      0          ERJ CRJ           United Airlines
# 17         4017.0       NaN      0              CR7                US Airways
# 18         4017.0       NaN      0              ERD                US Airways
# 19         4017.0         Y      0          ERD ER4                US Airways
#
#    Alias IATA ICAO   Callsign        Country Active International
# 0    NaN   9E  FLG   FLAGSHIP  United States      Y             N
# 1    NaN   AA  AAL   AMERICAN  United States      Y             N
# 2    NaN   AA  AAL   AMERICAN  United States      Y             N
# 3    NaN   AA  AAL   AMERICAN  United States      Y             N
# 4    NaN   AF  AFR   AIRFRANS         France      Y             Y
# 5    NaN   DL  DAL      DELTA  United States      Y             N
# 6    NaN   DL  DAL      DELTA  United States      Y             N
# 7    NaN   DL  DAL      DELTA  United States      Y             N
# 8    NaN   DL  DAL      DELTA  United States      Y             N
# 9    NaN   DL  DAL      DELTA  United States      Y             N
# 10   NaN   G4  AAY  ALLEGIANT  United States      Y             N
# 11   NaN   G4  AAY  ALLEGIANT  United States      Y             N
# 12   NaN   G4  AAY  ALLEGIANT  United States      Y             N
# 13   NaN   G4  AAY  ALLEGIANT  United States      Y             N
# 14   NaN   KL  KLM        KLM    Netherlands      Y             Y
# 15   NaN   UA  UAL     UNITED  United States      Y             N
# 16   NaN   UA  UAL     UNITED  United States      Y             N
# 17   NaN   US  USA    U S AIR  United States      Y             N
# 18   NaN   US  USA    U S AIR  United States      Y             N
# 19   NaN   US  USA    U S AIR  United States      Y             N

# %%
df_dep['International'] = 'Y'
df_dep
# Out:
#    Airline  AirlineID SourceAirport  SourceAirportID DestAirport  \
# 0       9E     3976.0           LEX           4017.0         ATL
# 1       AA       24.0           LEX           4017.0         CLT
# 2       AA       24.0           LEX           4017.0         DFW
# 3       AA       24.0           LEX           4017.0         ORD
# 4       AF      137.0           LEX           4017.0         ATL
# 5       DL     2009.0           LEX           4017.0         ATL
# 6       DL     2009.0           LEX           4017.0         DCA
# 7       DL     2009.0           LEX           4017.0         DTW
# 8       DL     2009.0           LEX           4017.0         LGA
# 9       DL     2009.0           LEX           4017.0         MSP
# 10      G4       35.0           LEX           4017.0         FLL
# 11      G4       35.0           LEX           4017.0         PGD
# 12      G4       35.0           LEX           4017.0         PIE
# 13      G4       35.0           LEX           4017.0         SFB
# 14      KL     3090.0           LEX           4017.0         ATL
# 15      UA     5209.0           LEX           4017.0         IAH
# 16      UA     5209.0           LEX           4017.0         ORD
# 17      US     5265.0           LEX           4017.0         CLT
# 18      US     5265.0           LEX           4017.0         DFW
# 19      US     5265.0           LEX           4017.0         ORD
#
#     DestAirportID Codeshare  Stops    Equipment                      Name  \
# 0          3682.0       NaN      0          CRJ         Pinnacle Airlines
# 1          3876.0         Y      0      CR7 CRJ         American Airlines
# 2          3670.0         Y      0      ERD ER4         American Airlines
# 3          3830.0         Y      0      ERD ER4         American Airlines
# 4          3682.0         Y      0      CRJ CR9                Air France
# 5          3682.0       NaN      0      M88 717           Delta Air Lines
# 6          3520.0         Y      0          CRJ           Delta Air Lines
# 7          3645.0         Y      0  CR7 CRJ CR9           Delta Air Lines
# 8          3697.0       NaN      0          ERJ           Delta Air Lines
# 9          3858.0         Y      0          CRJ           Delta Air Lines
# 10         3533.0       NaN      0          M80             Allegiant Air
# 11         7056.0       NaN      0          M80             Allegiant Air
# 12         3617.0       NaN      0          320             Allegiant Air
# 13         4167.0       NaN      0      M80 320             Allegiant Air
# 14         3682.0         Y      0      CR9 CRJ  KLM Royal Dutch Airlines
# 15         3550.0         Y      0          ERJ           United Airlines
# 16         3830.0         Y      0      ERJ CRJ           United Airlines
# 17         3876.0       NaN      0          CR7                US Airways
# 18         3670.0       NaN      0          ERD                US Airways
# 19         3830.0         Y      0      ERD ER4                US Airways
#
#    Alias IATA ICAO   Callsign        Country Active International
# 0    NaN   9E  FLG   FLAGSHIP  United States      Y             Y
# 1    NaN   AA  AAL   AMERICAN  United States      Y             Y
# 2    NaN   AA  AAL   AMERICAN  United States      Y             Y
# 3    NaN   AA  AAL   AMERICAN  United States      Y             Y
# 4    NaN   AF  AFR   AIRFRANS         France      Y             Y
# 5    NaN   DL  DAL      DELTA  United States      Y             Y
# 6    NaN   DL  DAL      DELTA  United States      Y             Y
# 7    NaN   DL  DAL      DELTA  United States      Y             Y
# 8    NaN   DL  DAL      DELTA  United States      Y             Y
# 9    NaN   DL  DAL      DELTA  United States      Y             Y
# 10   NaN   G4  AAY  ALLEGIANT  United States      Y             Y
# 11   NaN   G4  AAY  ALLEGIANT  United States      Y             Y
# 12   NaN   G4  AAY  ALLEGIANT  United States      Y             Y
# 13   NaN   G4  AAY  ALLEGIANT  United States      Y             Y
# 14   NaN   KL  KLM        KLM    Netherlands      Y             Y
# 15   NaN   UA  UAL     UNITED  United States      Y             Y
# 16   NaN   UA  UAL     UNITED  United States      Y             Y
# 17   NaN   US  USA    U S AIR  United States      Y             Y
# 18   NaN   US  USA    U S AIR  United States      Y             Y
# 19   NaN   US  USA    U S AIR  United States      Y             Y

# %%
for label in df_dep.index:
    if df_dep.Country[label] == 'United States':
        df_dep['International'][label] = 'N'
    else:
        df_dep['International'][label] = 'Y'
        
df_dep
# Out:
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Anaconda\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Airline  AirlineID SourceAirport  SourceAirportID DestAirport  \
# 0       9E     3976.0           LEX           4017.0         ATL
# 1       AA       24.0           LEX           4017.0         CLT
# 2       AA       24.0           LEX           4017.0         DFW
# 3       AA       24.0           LEX           4017.0         ORD
# 4       AF      137.0           LEX           4017.0         ATL
# 5       DL     2009.0           LEX           4017.0         ATL
# 6       DL     2009.0           LEX           4017.0         DCA
# 7       DL     2009.0           LEX           4017.0         DTW
# 8       DL     2009.0           LEX           4017.0         LGA
# 9       DL     2009.0           LEX           4017.0         MSP
# 10      G4       35.0           LEX           4017.0         FLL
# 11      G4       35.0           LEX           4017.0         PGD
# 12      G4       35.0           LEX           4017.0         PIE
# 13      G4       35.0           LEX           4017.0         SFB
# 14      KL     3090.0           LEX           4017.0         ATL
# 15      UA     5209.0           LEX           4017.0         IAH
# 16      UA     5209.0           LEX           4017.0         ORD
# 17      US     5265.0           LEX           4017.0         CLT
# 18      US     5265.0           LEX           4017.0         DFW
# 19      US     5265.0           LEX           4017.0         ORD
#
#     DestAirportID Codeshare  Stops    Equipment                      Name  \
# 0          3682.0       NaN      0          CRJ         Pinnacle Airlines
# 1          3876.0         Y      0      CR7 CRJ         American Airlines
# 2          3670.0         Y      0      ERD ER4         American Airlines
# 3          3830.0         Y      0      ERD ER4         American Airlines
# 4          3682.0         Y      0      CRJ CR9                Air France
# 5          3682.0       NaN      0      M88 717           Delta Air Lines
# 6          3520.0         Y      0          CRJ           Delta Air Lines
# 7          3645.0         Y      0  CR7 CRJ CR9           Delta Air Lines
# 8          3697.0       NaN      0          ERJ           Delta Air Lines
# 9          3858.0         Y      0          CRJ           Delta Air Lines
# 10         3533.0       NaN      0          M80             Allegiant Air
# 11         7056.0       NaN      0          M80             Allegiant Air
# 12         3617.0       NaN      0          320             Allegiant Air
# 13         4167.0       NaN      0      M80 320             Allegiant Air
# 14         3682.0         Y      0      CR9 CRJ  KLM Royal Dutch Airlines
# 15         3550.0         Y      0          ERJ           United Airlines
# 16         3830.0         Y      0      ERJ CRJ           United Airlines
# 17         3876.0       NaN      0          CR7                US Airways
# 18         3670.0       NaN      0          ERD                US Airways
# 19         3830.0         Y      0      ERD ER4                US Airways
#
#    Alias IATA ICAO   Callsign        Country Active International
# 0    NaN   9E  FLG   FLAGSHIP  United States      Y             N
# 1    NaN   AA  AAL   AMERICAN  United States      Y             N
# 2    NaN   AA  AAL   AMERICAN  United States      Y             N
# 3    NaN   AA  AAL   AMERICAN  United States      Y             N
# 4    NaN   AF  AFR   AIRFRANS         France      Y             Y
# 5    NaN   DL  DAL      DELTA  United States      Y             N
# 6    NaN   DL  DAL      DELTA  United States      Y             N
# 7    NaN   DL  DAL      DELTA  United States      Y             N
# 8    NaN   DL  DAL      DELTA  United States      Y             N
# 9    NaN   DL  DAL      DELTA  United States      Y             N
# 10   NaN   G4  AAY  ALLEGIANT  United States      Y             N
# 11   NaN   G4  AAY  ALLEGIANT  United States      Y             N
# 12   NaN   G4  AAY  ALLEGIANT  United States      Y             N
# 13   NaN   G4  AAY  ALLEGIANT  United States      Y             N
# 14   NaN   KL  KLM        KLM    Netherlands      Y             Y
# 15   NaN   UA  UAL     UNITED  United States      Y             N
# 16   NaN   UA  UAL     UNITED  United States      Y             N
# 17   NaN   US  USA    U S AIR  United States      Y             N
# 18   NaN   US  USA    U S AIR  United States      Y             N
# 19   NaN   US  USA    U S AIR  United States      Y             N

# %%
percent_int = len(df_dep[df_dep['DestAirport'] == 'CLT']) / len(df_arrive['Country'])
print(percent_int*100,'%')
# Out:
# 10.0 %

# %%
df_arrive.iteritems?

# %%
df_arrive['Country'].iteritems

# %%
percent_int = len(df_arrive[df_arrive['Country'] != 'United States']) / len(df_arrive['Country'])
print(percent_int*100,'%')
# Out:
# 10.0 %

# %%
percent_int = len(df_dep[df_dep['Country'] != 'United States']) / len(df_arrive['Country'])
print(percent_int*100,'%')
# Out:
# 10.0 %

# %%
percent_int = len(df_dep[df_dep['International'] != 'N']) / len(df_arrive['International'])
print(percent_int*100, '%')
# Out:
# 10.0 %

# %% [markdown]
# 5) Actually, it looks like a bunch of these routes are codeshares.  That means they are marketed by this airline, but operated by a different airline.  See the note in the data documentation on openflights.org/data.  The implication of this is that there are duplicates.
#
# Can you figure out which ones are duplicates?  Can you then create a dataframe with only the unique routes?  How many unique inbound and outbound routes are there?
#
# Remember, someone has to operate the flight, so if all the routes to/from a particular airport are listed as codeshares, then something is funny...
#
# It is also possible that more than one airline actually operates a route between the same two airports. (Having this sort of competition generally means that you will get better fares as a traveler.)  It may not be obvious what is actually in the data set, so dig or do external research as needed.

# %%
df_arrive.head()
# Out:
#   Airline  AirlineID SourceAirport  SourceAirportID DestAirport  \
# 0      9E     3976.0           ATL           3682.0         LEX
# 1      AA       24.0           CLT           3876.0         LEX
# 2      AA       24.0           DFW           3670.0         LEX
# 3      AA       24.0           ORD           3830.0         LEX
# 4      AF      137.0           ATL           3682.0         LEX
#
#    DestAirportID Codeshare  Stops        Equipment               Name Alias  \
# 0         4017.0       NaN      0              CRJ  Pinnacle Airlines   NaN
# 1         4017.0       NaN      0              CR7  American Airlines   NaN
# 2         4017.0         Y      0          ERD ER4  American Airlines   NaN
# 3         4017.0         Y      0          ERD ER4  American Airlines   NaN
# 4         4017.0         Y      0  CR9 M88 CRJ 717         Air France   NaN
#
#   IATA ICAO  Callsign        Country Active International
# 0   9E  FLG  FLAGSHIP  United States      Y             N
# 1   AA  AAL  AMERICAN  United States      Y             N
# 2   AA  AAL  AMERICAN  United States      Y             N
# 3   AA  AAL  AMERICAN  United States      Y             N
# 4   AF  AFR  AIRFRANS         France      Y             Y

# %%
df2 = df_arrive.dropna(axis = 0,thresh = 16)
print(len(df2))
#df2.drop(df[])
df2
# Out:
# 10
#    Airline  AirlineID SourceAirport  SourceAirportID DestAirport  \
# 2       AA       24.0           DFW           3670.0         LEX
# 3       AA       24.0           ORD           3830.0         LEX
# 4       AF      137.0           ATL           3682.0         LEX
# 6       DL     2009.0           DCA           3520.0         LEX
# 8       DL     2009.0           LGA           3697.0         LEX
# 9       DL     2009.0           MSP           3858.0         LEX
# 14      KL     3090.0           ATL           3682.0         LEX
# 15      UA     5209.0           IAH           3550.0         LEX
# 16      UA     5209.0           ORD           3830.0         LEX
# 19      US     5265.0           ORD           3830.0         LEX
#
#     DestAirportID Codeshare  Stops        Equipment                      Name  \
# 2          4017.0         Y      0          ERD ER4         American Airlines
# 3          4017.0         Y      0          ERD ER4         American Airlines
# 4          4017.0         Y      0  CR9 M88 CRJ 717                Air France
# 6          4017.0         Y      0              CRJ           Delta Air Lines
# 8          4017.0         Y      0              ERJ           Delta Air Lines
# 9          4017.0         Y      0              CRJ           Delta Air Lines
# 14         4017.0         Y      0      CR9 M88 CRJ  KLM Royal Dutch Airlines
# 15         4017.0         Y      0              ERJ           United Airlines
# 16         4017.0         Y      0          ERJ CRJ           United Airlines
# 19         4017.0         Y      0          ERD ER4                US Airways
#
#    Alias IATA ICAO  Callsign        Country Active International
# 2    NaN   AA  AAL  AMERICAN  United States      Y             N
# 3    NaN   AA  AAL  AMERICAN  United States      Y             N
# 4    NaN   AF  AFR  AIRFRANS         France      Y             Y
# 6    NaN   DL  DAL     DELTA  United States      Y             N
# 8    NaN   DL  DAL     DELTA  United States      Y             N
# 9    NaN   DL  DAL     DELTA  United States      Y             N
# 14   NaN   KL  KLM       KLM    Netherlands      Y             Y
# 15   NaN   UA  UAL    UNITED  United States      Y             N
# 16   NaN   UA  UAL    UNITED  United States      Y             N
# 19   NaN   US  USA   U S AIR  United States      Y             N

# %%
#looked at LEX master plan and saw that only these 4 airlines are serving the airport, thus they are the only unique routes
#found only the routes with those 4 airlines (already filtered by code share b/c codeshare may be another airline ad for one of the 4)
df_arrive2 = df2[df2.isin(['AA', 'DL','G4','UA'])]

df_arrive2 = df_arrive2.dropna(how = 'all')
print(len(df_arrive2))
df_arrive2
# Out:
# 7
#    Airline  AirlineID SourceAirport  SourceAirportID DestAirport  \
# 2       AA        NaN           NaN              NaN         NaN
# 3       AA        NaN           NaN              NaN         NaN
# 6       DL        NaN           NaN              NaN         NaN
# 8       DL        NaN           NaN              NaN         NaN
# 9       DL        NaN           NaN              NaN         NaN
# 15      UA        NaN           NaN              NaN         NaN
# 16      UA        NaN           NaN              NaN         NaN
#
#     DestAirportID Codeshare  Stops Equipment Name Alias IATA ICAO Callsign  \
# 2             NaN       NaN    NaN       NaN  NaN   NaN   AA  NaN      NaN
# 3             NaN       NaN    NaN       NaN  NaN   NaN   AA  NaN      NaN
# 6             NaN       NaN    NaN       NaN  NaN   NaN   DL  NaN      NaN
# 8             NaN       NaN    NaN       NaN  NaN   NaN   DL  NaN      NaN
# 9             NaN       NaN    NaN       NaN  NaN   NaN   DL  NaN      NaN
# 15            NaN       NaN    NaN       NaN  NaN   NaN   UA  NaN      NaN
# 16            NaN       NaN    NaN       NaN  NaN   NaN   UA  NaN      NaN
#
#    Country Active International
# 2      NaN    NaN           NaN
# 3      NaN    NaN           NaN
# 6      NaN    NaN           NaN
# 8      NaN    NaN           NaN
# 9      NaN    NaN           NaN
# 15     NaN    NaN           NaN
# 16     NaN    NaN           NaN

# %%
#look through the routes that dont have a codeshare to see if there are any airlines outside of the 4 mentioned before that are running
#there are 3 
#making the total number of unique arrivals 10
dfY = df_arrive[df_arrive['Codeshare'].isnull() ]
dfY
# Out:
#    Airline  AirlineID SourceAirport  SourceAirportID DestAirport  \
# 0       9E     3976.0           ATL           3682.0         LEX
# 1       AA       24.0           CLT           3876.0         LEX
# 5       DL     2009.0           ATL           3682.0         LEX
# 7       DL     2009.0           DTW           3645.0         LEX
# 10      G4       35.0           FLL           3533.0         LEX
# 11      G4       35.0           PGD           7056.0         LEX
# 12      G4       35.0           PIE           3617.0         LEX
# 13      G4       35.0           SFB           4167.0         LEX
# 17      US     5265.0           CLT           3876.0         LEX
# 18      US     5265.0           DFW           3670.0         LEX
#
#     DestAirportID Codeshare  Stops Equipment               Name Alias IATA  \
# 0          4017.0       NaN      0       CRJ  Pinnacle Airlines   NaN   9E
# 1          4017.0       NaN      0       CR7  American Airlines   NaN   AA
# 5          4017.0       NaN      0   M88 717    Delta Air Lines   NaN   DL
# 7          4017.0       NaN      0       717    Delta Air Lines   NaN   DL
# 10         4017.0       NaN      0       M80      Allegiant Air   NaN   G4
# 11         4017.0       NaN      0       M80      Allegiant Air   NaN   G4
# 12         4017.0       NaN      0       320      Allegiant Air   NaN   G4
# 13         4017.0       NaN      0   M80 320      Allegiant Air   NaN   G4
# 17         4017.0       NaN      0       CR7         US Airways   NaN   US
# 18         4017.0       NaN      0       ERD         US Airways   NaN   US
#
#    ICAO   Callsign        Country Active International
# 0   FLG   FLAGSHIP  United States      Y             N
# 1   AAL   AMERICAN  United States      Y             N
# 5   DAL      DELTA  United States      Y             N
# 7   DAL      DELTA  United States      Y             N
# 10  AAY  ALLEGIANT  United States      Y             N
# 11  AAY  ALLEGIANT  United States      Y             N
# 12  AAY  ALLEGIANT  United States      Y             N
# 13  AAY  ALLEGIANT  United States      Y             N
# 17  USA    U S AIR  United States      Y             N
# 18  USA    U S AIR  United States      Y             N

# %%
#same process for departures
df3 = df_dep.dropna(axis = 0,thresh = 16)
print(len(df3))

df3
# Out:
# 11
#    Airline  AirlineID SourceAirport  SourceAirportID DestAirport  \
# 1       AA       24.0           LEX           4017.0         CLT
# 2       AA       24.0           LEX           4017.0         DFW
# 3       AA       24.0           LEX           4017.0         ORD
# 4       AF      137.0           LEX           4017.0         ATL
# 6       DL     2009.0           LEX           4017.0         DCA
# 7       DL     2009.0           LEX           4017.0         DTW
# 9       DL     2009.0           LEX           4017.0         MSP
# 14      KL     3090.0           LEX           4017.0         ATL
# 15      UA     5209.0           LEX           4017.0         IAH
# 16      UA     5209.0           LEX           4017.0         ORD
# 19      US     5265.0           LEX           4017.0         ORD
#
#     DestAirportID Codeshare  Stops    Equipment                      Name  \
# 1          3876.0         Y      0      CR7 CRJ         American Airlines
# 2          3670.0         Y      0      ERD ER4         American Airlines
# 3          3830.0         Y      0      ERD ER4         American Airlines
# 4          3682.0         Y      0      CRJ CR9                Air France
# 6          3520.0         Y      0          CRJ           Delta Air Lines
# 7          3645.0         Y      0  CR7 CRJ CR9           Delta Air Lines
# 9          3858.0         Y      0          CRJ           Delta Air Lines
# 14         3682.0         Y      0      CR9 CRJ  KLM Royal Dutch Airlines
# 15         3550.0         Y      0          ERJ           United Airlines
# 16         3830.0         Y      0      ERJ CRJ           United Airlines
# 19         3830.0         Y      0      ERD ER4                US Airways
#
#    Alias IATA ICAO  Callsign        Country Active International
# 1    NaN   AA  AAL  AMERICAN  United States      Y             N
# 2    NaN   AA  AAL  AMERICAN  United States      Y             N
# 3    NaN   AA  AAL  AMERICAN  United States      Y             N
# 4    NaN   AF  AFR  AIRFRANS         France      Y             Y
# 6    NaN   DL  DAL     DELTA  United States      Y             N
# 7    NaN   DL  DAL     DELTA  United States      Y             N
# 9    NaN   DL  DAL     DELTA  United States      Y             N
# 14   NaN   KL  KLM       KLM    Netherlands      Y             Y
# 15   NaN   UA  UAL    UNITED  United States      Y             N
# 16   NaN   UA  UAL    UNITED  United States      Y             N
# 19   NaN   US  USA   U S AIR  United States      Y             N

# %%
df_dep2 = df3[df3.isin(['AA', 'DL','G4','UA'])]

df_dep2 = df_dep2.dropna(how = 'all')
print(len(df_dep2))
df_dep2
# Out:
# 8
#    Airline  AirlineID SourceAirport  SourceAirportID DestAirport  \
# 1       AA        NaN           NaN              NaN         NaN
# 2       AA        NaN           NaN              NaN         NaN
# 3       AA        NaN           NaN              NaN         NaN
# 6       DL        NaN           NaN              NaN         NaN
# 7       DL        NaN           NaN              NaN         NaN
# 9       DL        NaN           NaN              NaN         NaN
# 15      UA        NaN           NaN              NaN         NaN
# 16      UA        NaN           NaN              NaN         NaN
#
#     DestAirportID Codeshare  Stops Equipment Name Alias IATA ICAO Callsign  \
# 1             NaN       NaN    NaN       NaN  NaN   NaN   AA  NaN      NaN
# 2             NaN       NaN    NaN       NaN  NaN   NaN   AA  NaN      NaN
# 3             NaN       NaN    NaN       NaN  NaN   NaN   AA  NaN      NaN
# 6             NaN       NaN    NaN       NaN  NaN   NaN   DL  NaN      NaN
# 7             NaN       NaN    NaN       NaN  NaN   NaN   DL  NaN      NaN
# 9             NaN       NaN    NaN       NaN  NaN   NaN   DL  NaN      NaN
# 15            NaN       NaN    NaN       NaN  NaN   NaN   UA  NaN      NaN
# 16            NaN       NaN    NaN       NaN  NaN   NaN   UA  NaN      NaN
#
#    Country Active International
# 1      NaN    NaN           NaN
# 2      NaN    NaN           NaN
# 3      NaN    NaN           NaN
# 6      NaN    NaN           NaN
# 7      NaN    NaN           NaN
# 9      NaN    NaN           NaN
# 15     NaN    NaN           NaN
# 16     NaN    NaN           NaN

# %%
dfY2 = df_dep[df_dep['Codeshare'].isnull() ]
dfY2
#there are 3 flights outside of the 4 from the master plan that dont have a codeshare
#making the total 11 unique departure flights
# Out:
#    Airline  AirlineID SourceAirport  SourceAirportID DestAirport  \
# 0       9E     3976.0           LEX           4017.0         ATL
# 5       DL     2009.0           LEX           4017.0         ATL
# 8       DL     2009.0           LEX           4017.0         LGA
# 10      G4       35.0           LEX           4017.0         FLL
# 11      G4       35.0           LEX           4017.0         PGD
# 12      G4       35.0           LEX           4017.0         PIE
# 13      G4       35.0           LEX           4017.0         SFB
# 17      US     5265.0           LEX           4017.0         CLT
# 18      US     5265.0           LEX           4017.0         DFW
#
#     DestAirportID Codeshare  Stops Equipment               Name Alias IATA  \
# 0          3682.0       NaN      0       CRJ  Pinnacle Airlines   NaN   9E
# 5          3682.0       NaN      0   M88 717    Delta Air Lines   NaN   DL
# 8          3697.0       NaN      0       ERJ    Delta Air Lines   NaN   DL
# 10         3533.0       NaN      0       M80      Allegiant Air   NaN   G4
# 11         7056.0       NaN      0       M80      Allegiant Air   NaN   G4
# 12         3617.0       NaN      0       320      Allegiant Air   NaN   G4
# 13         4167.0       NaN      0   M80 320      Allegiant Air   NaN   G4
# 17         3876.0       NaN      0       CR7         US Airways   NaN   US
# 18         3670.0       NaN      0       ERD         US Airways   NaN   US
#
#    ICAO   Callsign        Country Active International
# 0   FLG   FLAGSHIP  United States      Y             N
# 5   DAL      DELTA  United States      Y             N
# 8   DAL      DELTA  United States      Y             N
# 10  AAY  ALLEGIANT  United States      Y             N
# 11  AAY  ALLEGIANT  United States      Y             N
# 12  AAY  ALLEGIANT  United States      Y             N
# 13  AAY  ALLEGIANT  United States      Y             N
# 17  USA    U S AIR  United States      Y             N
# 18  USA    U S AIR  United States      Y             N
